# %%
import numpy as np
import pandas as pd

# %%
orig_m = (pd.read_csv('current_monthly.csv').dropna(how='all'))
orig_q = (pd.read_csv('current_quarterly.csv').dropna(how='all'))
orig_m_GDP = (pd.read_csv('current_monthly_with_GDP.csv').dropna(how='all'))

# %%
orig_m_GDP
# Out:
#         sasdate        RPI  W875RX1  DPCERA3M086SBEA     CMRMTSPLx  \
# 0    Transform:      5.000      5.0            5.000  5.000000e+00
# 1      1/1/1959   2442.158   2293.2           17.272  2.922664e+05
# 2      2/1/1959   2451.778   2301.5           17.452  2.944247e+05
# 3      3/1/1959   2467.594   2318.5           17.617  2.934187e+05
# 4      4/1/1959   2483.671   2334.9           17.553  2.993228e+05
# ..          ...        ...      ...              ...           ...
# 753    9/1/2021  17755.780  14372.5          124.826  1.563118e+06
# 754   10/1/2021  17750.456  14405.1          125.811  1.570525e+06
# 755   11/1/2021  17748.960  14405.4          125.798  1.572464e+06
# 756   12/1/2021  17718.306  14393.3          124.139  1.559390e+06
# 757    1/1/2022  17625.517  14362.8          125.993           NaN
#
#           RETAILx    INDPRO   IPFPNSS   IPFINAL   IPCONGD  ...  \
# 0         5.00000    5.0000    5.0000    5.0000    5.0000  ...
# 1     18235.77392   22.0733   23.4027   22.2858   31.5688  ...
# 2     18369.56308   22.5056   23.7185   22.4788   31.8004  ...
# 3     18523.05762   22.8298   23.8621   22.5892   31.8004  ...
# 4     18534.46600   23.3161   24.2067   22.9201   32.3021  ...
# ..            ...       ...       ...       ...       ...  ...
# 753  626999.00000   99.8440   99.5027  100.1155   99.5807  ...
# 754  638102.00000  101.2341  100.2742  100.8704   99.9432  ...
# 755  642636.00000  102.1319  101.3514  101.8700  100.9974  ...
# 756  626289.00000  102.0234  100.9632  101.4493  100.3734  ...
# 757  649776.00000  103.4677  102.3319  103.1632  102.5825  ...
#
#      DSERRG3M086SBEA  CES0600000008  CES2000000008  CES3000000008  UMCSENTx  \
# 0              6.000           6.00           6.00           6.00       2.0
# 1             11.326           2.13           2.45           2.04       NaN
# 2             11.343           2.14           2.46           2.05       NaN
# 3             11.363           2.15           2.45           2.07       NaN
# 4             11.403           2.16           2.47           2.08       NaN
# ..               ...            ...            ...            ...       ...
# 753          125.243          26.81          30.76          24.10      72.8
# 754          125.641          26.88          30.95          24.17      71.7
# 755          126.255          26.99          31.04          24.24      67.4
# 756          126.837          27.15          31.23          24.37      70.6
# 757          127.368          27.27          31.44          24.48      67.2
#
#      DTCOLNVHFNM   DTCTHFNM     INVEST  VIXCLSx        GDP
# 0           6.00       6.00     6.0000   1.0000      5.000
# 1        6476.00   12298.00    84.2043      NaN        NaN
# 2        6476.00   12298.00    83.5280      NaN        NaN
# 3        6508.00   12349.00    81.6405      NaN   3123.978
# 4        6620.00   12484.00    81.8099      NaN        NaN
# ..           ...        ...        ...      ...        ...
# 753    370236.20  758672.57  5414.4515  19.7806  19478.893
# 754    369709.81  755505.40  5531.6054  17.7838        NaN
# 755    370323.53  754043.19  5599.1578  19.1586        NaN
# 756    368124.77  753384.15  5677.5001  21.2985  19810.572
# 757          NaN        NaN  5781.3852  22.9143        NaN
#
# [758 rows x 129 columns]

# %%
# 2. Extract transformation information
transform_m = orig_m_GDP.iloc[0, 1:]
orig_m_GDP = orig_m_GDP.iloc[1:]

# 3. Extract the date as an index
orig_m_GDP.index = pd.PeriodIndex(orig_m_GDP.sasdate.tolist(), freq='M')
orig_m_GDP.drop('sasdate', axis=1, inplace=True)

# %%
orig_m_GDP
# Out:
#                RPI  W875RX1  DPCERA3M086SBEA     CMRMTSPLx       RETAILx  \
# 1959-03   2467.594   2318.5           17.617  2.934187e+05   18523.05762
# 1959-04   2483.671   2334.9           17.553  2.993228e+05   18534.46600
# 1959-05   2498.026   2350.4           17.765  3.013643e+05   18679.66354
# 1959-06   2505.788   2357.4           17.831  3.013488e+05   18849.75209
# 1959-07   2504.312   2355.6           17.770  3.050203e+05   18843.52934
# ...            ...      ...              ...           ...           ...
# 2021-09  17755.780  14372.5          124.826  1.563118e+06  626999.00000
# 2021-10  17750.456  14405.1          125.811  1.570525e+06  638102.00000
# 2021-11  17748.960  14405.4          125.798  1.572464e+06  642636.00000
# 2021-12  17718.306  14393.3          124.139  1.559390e+06  626289.00000
# 2022-01  17625.517  14362.8          125.993           NaN  649776.00000
#
#            INDPRO   IPFPNSS   IPFINAL   IPCONGD  IPDCONGD  ...  \
# 1959-03   22.8298   23.8621   22.5892   31.8004   19.1254  ...
# 1959-04   23.3161   24.2067   22.9201   32.3021   19.2478  ...
# 1959-05   23.6673   24.4077   23.1408   32.4565   19.6396  ...
# 1959-06   23.6944   24.5800   23.3063   32.3021   19.7865  ...
# 1959-07   23.1270   24.6087   23.4993   32.7266   20.1784  ...
# ...           ...       ...       ...       ...       ...  ...
# 2021-09   99.8440   99.5027  100.1155   99.5807   99.1872  ...
# 2021-10  101.2341  100.2742  100.8704   99.9432  104.2676  ...
# 2021-11  102.1319  101.3514  101.8700  100.9974  105.4007  ...
# 2021-12  102.0234  100.9632  101.4493  100.3734  104.6822  ...
# 2022-01  103.4677  102.3319  103.1632  102.5825  104.6730  ...
#
#          DSERRG3M086SBEA  CES0600000008  CES2000000008  CES3000000008  \
# 1959-03           11.363           2.15           2.45           2.07
# 1959-04           11.403           2.16           2.47           2.08
# 1959-05           11.421           2.17           2.48           2.08
# 1959-06           11.463           2.17           2.50           2.09
# 1959-07           11.504           2.17           2.51           2.09
# ...                  ...            ...            ...            ...
# 2021-09          125.243          26.81          30.76          24.10
# 2021-10          125.641          26.88          30.95          24.17
# 2021-11          126.255          26.99          31.04          24.24
# 2021-12          126.837          27.15          31.23          24.37
# 2022-01          127.368          27.27          31.44          24.48
#
#          UMCSENTx  DTCOLNVHFNM   DTCTHFNM     INVEST  VIXCLSx        GDP
# 1959-03       NaN      6508.00   12349.00    81.6405      NaN   3123.978
# 1959-04       NaN      6620.00   12484.00    81.8099      NaN        NaN
# 1959-05      95.3      6753.00   12646.00    80.7315      NaN        NaN
# 1959-06       NaN      6956.00   12926.00    78.6972      NaN   3194.429
# 1959-07       NaN      7132.00   13199.00    78.9984      NaN        NaN
# ...           ...          ...        ...        ...      ...        ...
# 2021-09      72.8    370236.20  758672.57  5414.4515  19.7806  19478.893
# 2021-10      71.7    369709.81  755505.40  5531.6054  17.7838        NaN
# 2021-11      67.4    370323.53  754043.19  5599.1578  19.1586        NaN
# 2021-12      70.6    368124.77  753384.15  5677.5001  21.2985  19810.572
# 2022-01      67.2          NaN        NaN  5781.3852  22.9143        NaN
#
# [755 rows x 128 columns]

# %%
#fill NaN via linear interpolation
orig_m_GDP['GDP']=orig_m_GDP['GDP'].interpolate()

# %%
orig_m_GDP
# Out:
#                RPI  W875RX1  DPCERA3M086SBEA     CMRMTSPLx       RETAILx  \
# 1959-03   2467.594   2318.5           17.617  2.934187e+05   18523.05762
# 1959-04   2483.671   2334.9           17.553  2.993228e+05   18534.46600
# 1959-05   2498.026   2350.4           17.765  3.013643e+05   18679.66354
# 1959-06   2505.788   2357.4           17.831  3.013488e+05   18849.75209
# 1959-07   2504.312   2355.6           17.770  3.050203e+05   18843.52934
# ...            ...      ...              ...           ...           ...
# 2021-09  17755.780  14372.5          124.826  1.563118e+06  626999.00000
# 2021-10  17750.456  14405.1          125.811  1.570525e+06  638102.00000
# 2021-11  17748.960  14405.4          125.798  1.572464e+06  642636.00000
# 2021-12  17718.306  14393.3          124.139  1.559390e+06  626289.00000
# 2022-01  17625.517  14362.8          125.993           NaN  649776.00000
#
#            INDPRO   IPFPNSS   IPFINAL   IPCONGD  IPDCONGD  ...  \
# 1959-03   22.8298   23.8621   22.5892   31.8004   19.1254  ...
# 1959-04   23.3161   24.2067   22.9201   32.3021   19.2478  ...
# 1959-05   23.6673   24.4077   23.1408   32.4565   19.6396  ...
# 1959-06   23.6944   24.5800   23.3063   32.3021   19.7865  ...
# 1959-07   23.1270   24.6087   23.4993   32.7266   20.1784  ...
# ...           ...       ...       ...       ...       ...  ...
# 2021-09   99.8440   99.5027  100.1155   99.5807   99.1872  ...
# 2021-10  101.2341  100.2742  100.8704   99.9432  104.2676  ...
# 2021-11  102.1319  101.3514  101.8700  100.9974  105.4007  ...
# 2021-12  102.0234  100.9632  101.4493  100.3734  104.6822  ...
# 2022-01  103.4677  102.3319  103.1632  102.5825  104.6730  ...
#
#          DSERRG3M086SBEA  CES0600000008  CES2000000008  CES3000000008  \
# 1959-03           11.363           2.15           2.45           2.07
# 1959-04           11.403           2.16           2.47           2.08
# 1959-05           11.421           2.17           2.48           2.08
# 1959-06           11.463           2.17           2.50           2.09
# 1959-07           11.504           2.17           2.51           2.09
# ...                  ...            ...            ...            ...
# 2021-09          125.243          26.81          30.76          24.10
# 2021-10          125.641          26.88          30.95          24.17
# 2021-11          126.255          26.99          31.04          24.24
# 2021-12          126.837          27.15          31.23          24.37
# 2022-01          127.368          27.27          31.44          24.48
#
#          UMCSENTx  DTCOLNVHFNM   DTCTHFNM     INVEST  VIXCLSx           GDP
# 1959-03       NaN      6508.00   12349.00    81.6405      NaN   3123.978000
# 1959-04       NaN      6620.00   12484.00    81.8099      NaN   3147.461667
# 1959-05      95.3      6753.00   12646.00    80.7315      NaN   3170.945333
# 1959-06       NaN      6956.00   12926.00    78.6972      NaN   3194.429000
# 1959-07       NaN      7132.00   13199.00    78.9984      NaN   3195.180333
# ...           ...          ...        ...        ...      ...           ...
# 2021-09      72.8    370236.20  758672.57  5414.4515  19.7806  19478.893000
# 2021-10      71.7    369709.81  755505.40  5531.6054  17.7838  19589.452667
# 2021-11      67.4    370323.53  754043.19  5599.1578  19.1586  19700.012333
# 2021-12      70.6    368124.77  753384.15  5677.5001  21.2985  19810.572000
# 2022-01      67.2          NaN        NaN  5781.3852  22.9143  19810.572000
#
# [755 rows x 128 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
corrmat = orig_m_GDP.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(10,10))
g = sns.heatmap(orig_m_GDP[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
output = orig_m_GDP[top_corr_features].corr()
correlation = output.iloc[[127]]
correlation.sort_values('GDP',axis=1,ascending=False,inplace=True)
top_20 = correlation.iloc[:,0:19]
top_20
# Out:
# <ipython-input-66-fade68781c10>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   correlation.sort_values('GDP',axis=1,ascending=False,inplace=True)
#      GDP  DPCERA3M086SBEA   W875RX1  CMRMTSPLx       RPI  CUSR0000SAS  \
# GDP  1.0         0.999191  0.998705   0.996745  0.996017     0.995364
#
#      DSERRG3M086SBEA  CES0600000008  CES3000000008  BUSINVx  CPIAUCSL  \
# GDP         0.994687       0.993707       0.993072  0.99265  0.992157
#
#      CPIULFSL  CES2000000008  CPIMEDSL  CUSR0000SA0L5     IPMAT  \
# GDP  0.991852       0.991789  0.991346       0.990789  0.989885
#
#      CUSR0000SA0L2   RETAILx     PCEPI
# GDP       0.989245  0.988473  0.986434

# %%
t = top_20.T
t
# Out:
#                       GDP
# GDP              1.000000
# DPCERA3M086SBEA  0.999191
# W875RX1          0.998705
# CMRMTSPLx        0.996745
# RPI              0.996017
# CUSR0000SAS      0.995364
# DSERRG3M086SBEA  0.994687
# CES0600000008    0.993707
# CES3000000008    0.993072
# BUSINVx          0.992650
# CPIAUCSL         0.992157
# CPIULFSL         0.991852
# CES2000000008    0.991789
# CPIMEDSL         0.991346
# CUSR0000SA0L5    0.990789
# IPMAT            0.989885
# CUSR0000SA0L2    0.989245
# RETAILx          0.988473
# PCEPI            0.986434
